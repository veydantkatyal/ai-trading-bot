# %% [markdown]
# <a href="https://colab.research.google.com/github/veydantkatyal/ai-trading-bot/blob/main/botwise_RL_Portfolio_optmization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INSTALL DEPENDENCIES**

# %%
# !pip install stable-baselines3[extra] gym gym-anytrading pandas numpy matplotlib seaborn ccxt yfinance textblob vaderSentiment backtrader scipy flask fastapi uvicorn requests streamlit tensorflow torch transformers cvxpy optuna plotly shimmy>=2.0 stable-baselines3 gym numpy pandas
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.11/dist-packages)

# %% [markdown]
# # **FETCH LIVE MARKET DATA**

# %% [markdown]
# **Cryptocurrency Prices (Using CoinGecko API)**

# %%
import requests

crypto_symbols = ["ethereum", "bitcoin", "binancecoin", "ripple", "solana",
                  "cardano", "dogecoin", "polkadot", "avalanche-2", "chainlink"]

def fetch_crypto_prices(symbols=crypto_symbols):
    url = f"https://api.coingecko.com/api/v3/simple/price?ids={','.join(symbols)}&vs_currencies=usd"
    response = requests.get(url).json()
    return {symbol: response[symbol]["usd"] for symbol in symbols}

# Test
crypto_prices = fetch_crypto_prices()
print("Crypto Prices:", crypto_prices)
# Out:
# Crypto Prices: {'ethereum': 2708.72, 'bitcoin': 97774, 'binancecoin': 661.75, 'ripple': 2.81, 'solana': 195.31, 'cardano': 0.79293, 'dogecoin': 0.278465, 'polkadot': 5.1, 'avalanche-2': 26.12, 'chainlink': 19.17}

# %% [markdown]
# **Stock Prices (Using Yahoo Finance)**

# %%
import yfinance as yf

stock_symbols = ["AAPL", "TSLA", "GOOGL", "AMZN", "MSFT", "META", "NVDA", "NFLX", "INTC", "IBM"]

def fetch_stock_prices(symbols=stock_symbols):
    prices = {}
    for symbol in symbols:
        stock = yf.Ticker(symbol)
        prices[symbol] = stock.history(period="1d", interval="1h")['Close'].iloc[-1]
    return prices

# Test
stock_prices = fetch_stock_prices()
print("Stock Prices:", stock_prices)
# Out:
# Stock Prices: {'AAPL': 244.57000732421875, 'TSLA': 355.8999938964844, 'GOOGL': 185.1699981689453, 'AMZN': 228.67999267578125, 'MSFT': 408.3299865722656, 'META': 736.5999755859375, 'NVDA': 138.86000061035156, 'NFLX': 1058.780029296875, 'INTC': 23.610000610351562, 'IBM': 261.2099914550781}

# %% [markdown]
# **Forex Prices (Using Alpha Vantage API)**

# %%
import requests

# Define Forex currency pairs
forex_pairs = [("EUR", "USD"), ("GBP", "USD"), ("USD", "JPY"), ("AUD", "USD"), ("USD", "CAD"),
               ("USD", "CHF"), ("NZD", "USD"), ("EUR", "GBP"), ("EUR", "JPY"), ("GBP", "JPY")]

EXCHANGERATE_API_KEY = "YOUR_API_KEY"
FOREX_URL = f"https://v6.exchangerate-api.com/v6/{EXCHANGERATE_API_KEY}/latest/"

def fetch_forex_prices(pairs=forex_pairs):
    prices = {}
    for from_currency, to_currency in pairs:
        try:
            url = f"{FOREX_URL}{from_currency}"
            response = requests.get(url).json()
            rates = response.get("conversion_rates", {})
            if to_currency in rates:
                prices[f"{from_currency}/{to_currency}"] = rates[to_currency]
            else:
                prices[f"{from_currency}/{to_currency}"] = None
                print(f"Error fetching {from_currency}/{to_currency}: No data found")
        except Exception as e:
            prices[f"{from_currency}/{to_currency}"] = None
            print(f"Error fetching {from_currency}/{to_currency}: {e}")

    return prices

# Test
forex_prices = fetch_forex_prices()
print("Forex Prices:", forex_prices)
# Out:
# Forex Prices: {'EUR/USD': 1.0492, 'GBP/USD': 1.2585, 'USD/JPY': 152.3849, 'AUD/USD': 0.6349, 'USD/CAD': 1.4176, 'USD/CHF': 0.8996, 'NZD/USD': 0.5724, 'EUR/GBP': 0.8332, 'EUR/JPY': 159.7919, 'GBP/JPY': 191.8276}

# %% [markdown]
# **Commodity Prices (Using Yahoo Finance)**

# %%
import yfinance as yf

# Define commodity tickers from Yahoo Finance
commodity_tickers = {
    "Gold": "GC=F",
    "Silver": "SI=F",
    "Platinum": "PL=F",
    "Palladium": "PA=F",
    "Crude Oil WTI": "CL=F",
    "Crude Oil Brent": "BZ=F",
    "Natural Gas": "NG=F",
    "Copper": "HG=F",
    "Aluminum": "ALI=F"
}

def fetch_commodity_prices():
    prices = {}
    for name, ticker in commodity_tickers.items():
        try:
            data = yf.Ticker(ticker)
            hist = data.history(period="1d")
            if not hist.empty:
                prices[name] = hist['Close'].iloc[-1]
            else:
                prices[name] = None
                print(f"No data found for {name}")
        except Exception as e:
            prices[name] = None
            print(f"Error fetching {name}: {e}")
    return prices

# Test
commodity_prices = fetch_commodity_prices()
print("Updated Commodity Prices:", commodity_prices)
# Out:
# Updated Commodity Prices: {'Gold': 2883.60009765625, 'Silver': 32.80099868774414, 'Platinum': 1009.7999877929688, 'Palladium': 1005.0, 'Crude Oil WTI': 70.73999786376953, 'Crude Oil Brent': 74.73999786376953, 'Natural Gas': 3.7249999046325684, 'Copper': 4.656499862670898, 'Aluminum': 2612.25}

# %% [markdown]
# **Consolidate All Asset Prices**

# %%
assets = {
    "Crypto": fetch_crypto_prices(),
    "Stocks": fetch_stock_prices(),
    "Forex": fetch_forex_prices(),
    "Commodities": fetch_commodity_prices()
}

print("All Asset Prices:", assets)
# Out:
# All Asset Prices: {'Crypto': {'ethereum': 2708.72, 'bitcoin': 97774, 'binancecoin': 661.75, 'ripple': 2.81, 'solana': 195.31, 'cardano': 0.79293, 'dogecoin': 0.278465, 'polkadot': 5.1, 'avalanche-2': 26.12, 'chainlink': 19.17}, 'Stocks': {'AAPL': 244.57000732421875, 'TSLA': 355.8999938964844, 'GOOGL': 185.1699981689453, 'AMZN': 228.67999267578125, 'MSFT': 408.3299865722656, 'META': 736.5999755859375, 'NVDA': 138.86000061035156, 'NFLX': 1058.780029296875, 'INTC': 23.610000610351562, 'IBM': 261.2099914550781}, 'Forex': {'EUR/USD': 1.0492, 'GBP/USD': 1.2585, 'USD/JPY': 152.3849, 'AUD/USD': 0.6349, 'USD/CAD': 1.4176, 'USD/CHF': 0.8996, 'NZD/USD': 0.5724, 'EUR/GBP': 0.8332, 'EUR/JPY': 159.7919, 'GBP/JPY': 191.8276}, 'Commodities': {'Gold': 2883.60009765625, 'Silver': 32.80099868774414, 'Platinum': 1009.7999877929688, 'Palladium': 1005.0, 'Crude Oil WTI': 70.73999786376953, 'Crude Oil Brent': 74.73999786376953, 'Natural Gas': 3.7249999046325684, 'Copper': 4.656499862670898, 'Aluminum': 2612.25}}

# %% [markdown]
# # **AI-Based Portfolio Optimization**

# %% [markdown]
# * Markowitz Mean-Variance Optimization (Classic Portfolio Theory)
# * Reinforcement Learning-Based Portfolio Optimization (Deep Q-Learning)

# %% [markdown]
# **Markowitz Approach**
#
# This method finds the optimal asset allocation that maximizes return while minimizing risk.

# %%
import numpy as np
import cvxpy as cp

# Simulated historical returns for each asset class
returns = np.array([
    [0.01, 0.02, 0.015, 0.005, -0.002],  # Crypto
    [0.012, 0.018, 0.01, 0.008, 0.002],  # Stocks
    [0.007, 0.011, 0.009, 0.006, 0.001],  # Forex
    [0.005, 0.007, 0.006, 0.003, -0.001]  # Commodities
]).T

# Number of assets
num_assets = returns.shape[1]

# Define optimization variables
weights = cp.Variable(num_assets)

# Calculate expected returns (you can replace this with your desired method)
expected_return = np.mean(returns, axis=0)

# Define the expected_return parameter and assign the calculated values
expected_return_param = cp.Parameter(num_assets, nonneg=True, value=expected_return)

# Calculate covariance matrix
cov_matrix = np.cov(returns.T)

# Use the expected_return_param in the objective function
objective = cp.Maximize(expected_return_param @ weights - 0.5 * cp.quad_form(weights, cov_matrix))
constraints = [cp.sum(weights) == 1, weights >= 0]

# Solve optimization problem
problem = cp.Problem(objective, constraints)
problem.solve()

# Display Optimized Portfolio Weights
optimized_weights = weights.value
print("Optimized Portfolio Weights:", optimized_weights)
# Out:
# Optimized Portfolio Weights: [-1.73464598e-22  1.00000000e+00 -3.03440701e-27 -4.41602409e-27]

# %% [markdown]
# **RL Approach**
#
# We use Deep Deterministic Policy Gradient(DDPG) to dynamically allocate assets based on market conditions.

# %%
import gym
import numpy as np
#from gym import spaces  # Original import
from gymnasium import spaces  # Import from gymnasium instead of gym
# Import necessary modules for compatibility
import shimmy
# Correct import statement for gymnasium
import gymnasium as gym

class PortfolioEnv(gym.Env):
    def __init__(self, asset_prices, initial_balance=10000):
        super(PortfolioEnv, self).__init__()

        self.asset_prices = asset_prices
        self.num_assets = asset_prices.shape[1]
        self.initial_balance = initial_balance
        self.current_balance = initial_balance
        self.current_step = 0

        # Action space: Allocate % of portfolio to each asset
        self.action_space = spaces.Box(low=0, high=1, shape=(self.num_assets,), dtype=np.float32)

        # Observation space: Asset prices and balance
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(self.num_assets + 1,), dtype=np.float32)

    def reset(self, seed=None, options=None): # Add seed and options argument
        super().reset(seed=seed) # Pass seed to super().reset()
        self.current_balance = self.initial_balance
        self.current_step = 0
        return self._next_observation(), {} # Return info dict

    def _next_observation(self):
        obs = np.append(self.asset_prices[self.current_step], self.current_balance)
        return obs

    def step(self, action):
        allocation = action / np.sum(action)  # Normalize allocation
        self.current_balance *= 1 + np.dot(allocation, self.asset_prices[self.current_step] / self.asset_prices[self.current_step - 1] - 1)
        self.current_step += 1

        done = self.current_step >= len(self.asset_prices) - 1
        # Return observation, reward, terminated, truncated, info
        # In this case, we'll set terminated to done and truncated to False
        return self._next_observation(), self.current_balance, done, False, {}

    def render(self):
        print(f"Step: {self.current_step}, Balance: {self.current_balance}")

# %%
from stable_baselines3 import DQN, DDPG

# Simulated Asset Prices for Training (Replace with real data)
np.random.seed(42)
asset_prices = np.random.rand(1000, 4) * 100  # 1000 time steps, 4 assets

# Create environment
env = PortfolioEnv(asset_prices)

# Train DQN model
model = DDPG("MlpPolicy", env, learning_rate=0.0003, gamma=0.99, batch_size=64, verbose=1)
model.learn(total_timesteps=500000)
model.save("ddpg_portfolio_optimizer")

print("Reinforcement Learning Portfolio Optimization Model Trained Successfully!")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 155      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 3996     |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3895     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 155      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 7992     |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7891     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 156      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 11988    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 156      |
# |    time_elapsed    | 102      |
# |    total_timesteps | 15984    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15883    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 152      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 19980    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 153      |
# |    time_elapsed    | 156      |
# |    total_timesteps | 23976    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23875    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 153      |
# |    time_elapsed    | 182      |
# |    total_timesteps | 27972    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27871    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 153      |
# |    time_elapsed    | 208      |
# |    total_timesteps | 31968    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 154      |
# |    time_elapsed    | 233      |
# |    total_timesteps | 35964    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35863    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 154      |
# |    time_elapsed    | 259      |
# |    total_timesteps | 39960    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39859    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 154      |
# |    time_elapsed    | 284      |
# |    total_timesteps | 43956    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43855    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 153      |
# |    time_elapsed    | 311      |
# |    total_timesteps | 47952    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47851    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 153      |
# |    time_elapsed    | 337      |
# |    total_timesteps | 51948    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51847    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 153      |
# |    time_elapsed    | 363      |
# |    total_timesteps | 55944    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 154      |
# |    time_elapsed    | 389      |
# |    total_timesteps | 59940    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59839    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 154      |
# |    time_elapsed    | 414      |
# |    total_timesteps | 63936    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63835    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 154      |
# |    time_elapsed    | 441      |
# |    total_timesteps | 67932    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67831    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 154      |
# |    time_elapsed    | 466      |
# |    total_timesteps | 71928    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71827    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 154      |
# |    time_elapsed    | 492      |
# |    total_timesteps | 75924    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75823    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 154      |
# |    time_elapsed    | 518      |
# |    total_timesteps | 79920    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 154      |
# |    time_elapsed    | 543      |
# |    total_timesteps | 83916    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83815    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 154      |
# |    time_elapsed    | 569      |
# |    total_timesteps | 87912    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87811    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 154      |
# |    time_elapsed    | 594      |
# |    total_timesteps | 91908    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91807    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 154      |
# |    time_elapsed    | 620      |
# |    total_timesteps | 95904    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95803    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 154      |
# |    time_elapsed    | 646      |
# |    total_timesteps | 99900    |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 154      |
# |    time_elapsed    | 672      |
# |    total_timesteps | 103896   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103795   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 154      |
# |    time_elapsed    | 697      |
# |    total_timesteps | 107892   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107791   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 154      |
# |    time_elapsed    | 722      |
# |    total_timesteps | 111888   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111787   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 154      |
# |    time_elapsed    | 748      |
# |    total_timesteps | 115884   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115783   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 154      |
# |    time_elapsed    | 773      |
# |    total_timesteps | 119880   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 154      |
# |    time_elapsed    | 800      |
# |    total_timesteps | 123876   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123775   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 154      |
# |    time_elapsed    | 825      |
# |    total_timesteps | 127872   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127771   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 154      |
# |    time_elapsed    | 851      |
# |    total_timesteps | 131868   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131767   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 154      |
# |    time_elapsed    | 876      |
# |    total_timesteps | 135864   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135763   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 155      |
# |    time_elapsed    | 902      |
# |    total_timesteps | 139860   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 139759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 155      |
# |    time_elapsed    | 927      |
# |    total_timesteps | 143856   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143755   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 154      |
# |    time_elapsed    | 953      |
# |    total_timesteps | 147852   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147751   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 155      |
# |    time_elapsed    | 979      |
# |    total_timesteps | 151848   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151747   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 154      |
# |    time_elapsed    | 1006     |
# |    total_timesteps | 155844   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 155743   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 154      |
# |    time_elapsed    | 1032     |
# |    total_timesteps | 159840   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 159739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 154      |
# |    time_elapsed    | 1057     |
# |    total_timesteps | 163836   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 163735   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 154      |
# |    time_elapsed    | 1083     |
# |    total_timesteps | 167832   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 167731   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 154      |
# |    time_elapsed    | 1109     |
# |    total_timesteps | 171828   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 171727   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 154      |
# |    time_elapsed    | 1134     |
# |    total_timesteps | 175824   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175723   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 154      |
# |    time_elapsed    | 1160     |
# |    total_timesteps | 179820   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179719   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 154      |
# |    time_elapsed    | 1186     |
# |    total_timesteps | 183816   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183715   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 155      |
# |    time_elapsed    | 1211     |
# |    total_timesteps | 187812   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187711   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 155      |
# |    time_elapsed    | 1236     |
# |    total_timesteps | 191808   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 191707   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 155      |
# |    time_elapsed    | 1262     |
# |    total_timesteps | 195804   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 195703   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 155      |
# |    time_elapsed    | 1288     |
# |    total_timesteps | 199800   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 199699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 155      |
# |    time_elapsed    | 1313     |
# |    total_timesteps | 203796   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 203695   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 155      |
# |    time_elapsed    | 1339     |
# |    total_timesteps | 207792   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207691   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 155      |
# |    time_elapsed    | 1364     |
# |    total_timesteps | 211788   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211687   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 155      |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 215784   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 215683   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 155      |
# |    time_elapsed    | 1415     |
# |    total_timesteps | 219780   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 219679   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 155      |
# |    time_elapsed    | 1441     |
# |    total_timesteps | 223776   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223675   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 155      |
# |    time_elapsed    | 1466     |
# |    total_timesteps | 227772   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227671   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 155      |
# |    time_elapsed    | 1492     |
# |    total_timesteps | 231768   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231667   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 155      |
# |    time_elapsed    | 1517     |
# |    total_timesteps | 235764   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 155      |
# |    time_elapsed    | 1542     |
# |    total_timesteps | 239760   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 239659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 155      |
# |    time_elapsed    | 1568     |
# |    total_timesteps | 243756   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243655   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 155      |
# |    time_elapsed    | 1594     |
# |    total_timesteps | 247752   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 247651   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 155      |
# |    time_elapsed    | 1619     |
# |    total_timesteps | 251748   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 251647   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 155      |
# |    time_elapsed    | 1645     |
# |    total_timesteps | 255744   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255643   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 155      |
# |    time_elapsed    | 1670     |
# |    total_timesteps | 259740   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259639   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 155      |
# |    time_elapsed    | 1695     |
# |    total_timesteps | 263736   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263635   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 155      |
# |    time_elapsed    | 1721     |
# |    total_timesteps | 267732   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267631   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 155      |
# |    time_elapsed    | 1746     |
# |    total_timesteps | 271728   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 271627   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 155      |
# |    time_elapsed    | 1772     |
# |    total_timesteps | 275724   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 275623   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 155      |
# |    time_elapsed    | 1798     |
# |    total_timesteps | 279720   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 279619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 155      |
# |    time_elapsed    | 1823     |
# |    total_timesteps | 283716   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283615   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 155      |
# |    time_elapsed    | 1849     |
# |    total_timesteps | 287712   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 287611   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 155      |
# |    time_elapsed    | 1874     |
# |    total_timesteps | 291708   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 291607   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 155      |
# |    time_elapsed    | 1899     |
# |    total_timesteps | 295704   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 295603   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 155      |
# |    time_elapsed    | 1925     |
# |    total_timesteps | 299700   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299599   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 155      |
# |    time_elapsed    | 1950     |
# |    total_timesteps | 303696   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 303595   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 155      |
# |    time_elapsed    | 1976     |
# |    total_timesteps | 307692   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 307591   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 155      |
# |    time_elapsed    | 2001     |
# |    total_timesteps | 311688   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 311587   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 155      |
# |    time_elapsed    | 2027     |
# |    total_timesteps | 315684   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 315583   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 155      |
# |    time_elapsed    | 2052     |
# |    total_timesteps | 319680   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 319579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 155      |
# |    time_elapsed    | 2078     |
# |    total_timesteps | 323676   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 323575   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 155      |
# |    time_elapsed    | 2105     |
# |    total_timesteps | 327672   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327571   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 155      |
# |    time_elapsed    | 2130     |
# |    total_timesteps | 331668   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 331567   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 155      |
# |    time_elapsed    | 2156     |
# |    total_timesteps | 335664   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 335563   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 155      |
# |    time_elapsed    | 2182     |
# |    total_timesteps | 339660   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 339559   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 155      |
# |    time_elapsed    | 2207     |
# |    total_timesteps | 343656   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 343555   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 155      |
# |    time_elapsed    | 2232     |
# |    total_timesteps | 347652   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 347551   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 155      |
# |    time_elapsed    | 2258     |
# |    total_timesteps | 351648   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 351547   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 155      |
# |    time_elapsed    | 2284     |
# |    total_timesteps | 355644   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 355543   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 155      |
# |    time_elapsed    | 2309     |
# |    total_timesteps | 359640   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 359539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 155      |
# |    time_elapsed    | 2335     |
# |    total_timesteps | 363636   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 363535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 155      |
# |    time_elapsed    | 2361     |
# |    total_timesteps | 367632   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 367531   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 155      |
# |    time_elapsed    | 2386     |
# |    total_timesteps | 371628   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 371527   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 155      |
# |    time_elapsed    | 2412     |
# |    total_timesteps | 375624   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 375523   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 155      |
# |    time_elapsed    | 2438     |
# |    total_timesteps | 379620   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 379519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 155      |
# |    time_elapsed    | 2463     |
# |    total_timesteps | 383616   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 383515   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 155      |
# |    time_elapsed    | 2489     |
# |    total_timesteps | 387612   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 387511   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 155      |
# |    time_elapsed    | 2514     |
# |    total_timesteps | 391608   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 391507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 155      |
# |    time_elapsed    | 2540     |
# |    total_timesteps | 395604   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 395503   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 155      |
# |    time_elapsed    | 2566     |
# |    total_timesteps | 399600   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 399499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 155      |
# |    time_elapsed    | 2591     |
# |    total_timesteps | 403596   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 403495   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 155      |
# |    time_elapsed    | 2617     |
# |    total_timesteps | 407592   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 407491   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 155      |
# |    time_elapsed    | 2642     |
# |    total_timesteps | 411588   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 411487   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 155      |
# |    time_elapsed    | 2667     |
# |    total_timesteps | 415584   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 415483   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 155      |
# |    time_elapsed    | 2693     |
# |    total_timesteps | 419580   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 419479   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 155      |
# |    time_elapsed    | 2718     |
# |    total_timesteps | 423576   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 423475   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 155      |
# |    time_elapsed    | 2745     |
# |    total_timesteps | 427572   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 427471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 155      |
# |    time_elapsed    | 2770     |
# |    total_timesteps | 431568   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 431467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 155      |
# |    time_elapsed    | 2795     |
# |    total_timesteps | 435564   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 435463   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 155      |
# |    time_elapsed    | 2821     |
# |    total_timesteps | 439560   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 439459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 155      |
# |    time_elapsed    | 2846     |
# |    total_timesteps | 443556   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 443455   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 155      |
# |    time_elapsed    | 2871     |
# |    total_timesteps | 447552   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 447451   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 155      |
# |    time_elapsed    | 2896     |
# |    total_timesteps | 451548   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 451447   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 155      |
# |    time_elapsed    | 2923     |
# |    total_timesteps | 455544   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 455443   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 155      |
# |    time_elapsed    | 2948     |
# |    total_timesteps | 459540   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 459439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 155      |
# |    time_elapsed    | 2974     |
# |    total_timesteps | 463536   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 463435   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 155      |
# |    time_elapsed    | 2999     |
# |    total_timesteps | 467532   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 467431   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 155      |
# |    time_elapsed    | 3024     |
# |    total_timesteps | 471528   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 471427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 155      |
# |    time_elapsed    | 3049     |
# |    total_timesteps | 475524   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 155      |
# |    time_elapsed    | 3075     |
# |    total_timesteps | 479520   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 479419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 155      |
# |    time_elapsed    | 3101     |
# |    total_timesteps | 483516   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483415   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 155      |
# |    time_elapsed    | 3126     |
# |    total_timesteps | 487512   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487411   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 155      |
# |    time_elapsed    | 3151     |
# |    total_timesteps | 491508   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 491407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 155      |
# |    time_elapsed    | 3177     |
# |    total_timesteps | 495504   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 495403   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | nan      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 155      |
# |    time_elapsed    | 3202     |
# |    total_timesteps | 499500   |
# | train/             |          |
# |    actor_loss      | nan      |
# |    critic_loss     | nan      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499399   |
# ---------------------------------
# Reinforcement Learning Portfolio Optimization Model Trained Successfully!
